# %% [markdown]
# ## Joining the postcodes with coordinates
#
# First, I read in the previous dataframe

# %%
import pandas as pd
df_grouped = pd.read_csv('Toronto_PostCodes.csv', index_col = 0)
df_grouped.head()
# Out:
#   Postcode          Borough                                      Neighbourhood
# 0      M1E      Scarborough                  Guildwood, Morningside, West Hill
# 1      M4S  Central Toronto                                         Davisville
# 2      M9B        Etobicoke  Cloverdale, Islington, Martin Grove, Princess ...
# 3      M8V        Etobicoke       Humber Bay Shores, Mimico South, New Toronto
# 4      M8W        Etobicoke                             Alderwood, Long Branch

# %% [markdown]
# I tried using **geocoder** but it took forever to even get a single postcode (see below), so I am reading in the CSV.

# %%
df_coord = pd.read_csv('http://cocl.us/Geospatial_data')
df_coord.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# ## Merging the two dataframes to get a df with Postcodes, Names, and Coordinates

# %%
df_left = pd.merge(df_grouped, df_coord, how='left', left_on='Postcode',right_on='Postal Code')
df_left
# Out:
#     Postcode           Borough  \
# 0        M1E       Scarborough
# 1        M4S   Central Toronto
# 2        M9B         Etobicoke
# 3        M8V         Etobicoke
# 4        M8W         Etobicoke
# 5        M5X  Downtown Toronto
# 6        M4L      East Toronto
# 7        M4Y  Downtown Toronto
# 8        M4R   Central Toronto
# 9        M4X  Downtown Toronto
# 10       M2P        North York
# 11       M4B         East York
# 12       M2M        North York
# 13       M9A         Etobicoke
# 14       M2J        North York
# 15       M5B  Downtown Toronto
# 16       M1P       Scarborough
# 17       M3A        North York
# 18       M3M        North York
# 19       M4P   Central Toronto
# 20       M3H        North York
# 21       M1X       Scarborough
# 22       M8Y         Etobicoke
# 23       M8X         Etobicoke
# 24       M2K        North York
# 25       M2L        North York
# 26       M1B       Scarborough
# 27       M9R         Etobicoke
# 28       M1H       Scarborough
# ...

# %%
import geocoder # import geocoder

postal_code = 'M7Y'

# initialize your variable to None
lat_lng_coords = None

# loop until you get the coordinates
while(lat_lng_coords is None):
  g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
  lat_lng_coords = g.latlng

latitude = lat_lng_coords[0]
longitude = lat_lng_coords[1]
# initialize your variable to None
lat_lng_coords = None

# loop until you get the coordinates
while(lat_lng_coords is None):
  g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
  lat_lng_coords = g.latlng

latitude = lat_lng_coords[0]
longitude = lat_lng_coords[1]
